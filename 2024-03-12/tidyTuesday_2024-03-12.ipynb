# %% [markdown]
# # TidyTuesday 2024-03-12 - Python
# See: https://github.com/rfordatascience/tidytuesday/blob/master/data/2024/2024-03-12/readme.md

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# to beautify our plots
plt.style.use('ggplot')

# %%
fiscal_sponsors = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2024/2024-03-12/fiscal_sponsor_directory.csv')

fiscal_sponsors.head(3)
# Out:
#                                          details_url  \
# 0    https://fiscalsponsordirectory.org/?page_id=599
# 1  https://fiscalsponsordirectory.org/?page_id=12459
# 2    https://fiscalsponsordirectory.org/?page_id=781
#
#                         name          website  year_501c3  \
# 0  1st Note Music Foundation  www.1stnote.org      2012.0
# 1                50CAN, Inc.        50can.org      2011.0
# 2   The Abundance Foundation  abundancenc.org      2006.0
#
#    year_fiscal_sponsor  n_sponsored  \
# 0               2012.0          2.0
# 1               2016.0         10.0
# 2               2007.0         20.0
#
#                   fiscal_sponsorship_fee_description  \
# 0  We charge a 7% administrative fee for most gra...
# 1                               Between 7.5% and 15%
# 2  We charge 9-15% to work with an organization o...
#
#                                 eligibility_criteria  \
# 0            Type of service: Music related projects
# ...
